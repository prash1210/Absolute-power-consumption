# %%
cd D:\Prashant Documents\Seminar
# Out:
# D:\Prashant Documents\Seminar

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_excel("Book1.xlsx","Daily analysis")
df
# Out:
#          Date  Anode Production no.  Anode weight  Anode Production\n(Ton)  \
# 0  2021-05-01                  1580        0.9842                1555.0360
# 1  2021-05-02                  1557        0.9842                1532.3994
# 2  2021-05-03                  1883        0.9842                1853.2486
# 3  2021-05-04                  1928        0.9842                1897.5376
# 4  2021-05-05                  1471        0.9842                1447.7582
# 5  2021-05-06                  1933        0.9842                1902.4586
# 6  2021-05-07                  1694        0.9842                1667.2348
# 7  2021-05-08                  1608        0.9842                1582.5936
# 8  2021-05-09                  1329        0.9842                1308.0018
# 9  2021-05-10                  2046        0.9842                2013.6732
# 10 2021-05-11                  1745        0.9842                1717.4290
# ...

# %%
df.head()
# Out:
#         Date  Anode Production no.  Anode weight  Anode Production\n(Ton)  \
# 0 2021-05-01                  1580        0.9842                1555.0360
# 1 2021-05-02                  1557        0.9842                1532.3994
# 2 2021-05-03                  1883        0.9842                1853.2486
# 3 2021-05-04                  1928        0.9842                1897.5376
# 4 2021-05-05                  1471        0.9842                1447.7582
#
#    Bath Production  Absolue energy  Mill Absolute energy  \
# 0           834.72           82020               23320.0
# 1          1152.58           86190               23940.0
# 2           952.47           88840               22190.0
# 3           904.54           89880               20600.0
# 4          1037.44           78440               21590.0
#
#    Furnace Absolute energy  Aux Absolute energy  Mill 1 Running hours  ...  \
# 0                  37100.0              21390.0                 19.08  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 28 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Date                                31 non-null     datetime64[ns]
#  1   Anode Production no.                31 non-null     int64
#  2   Anode weight                        31 non-null     float64
#  3   Anode Production
# (Ton)              31 non-null     float64
#  4   Bath Production                     31 non-null     float64
#  5   Absolue energy                      31 non-null     int64
#  6   Mill Absolute energy                31 non-null     float64
#  7   Furnace Absolute energy             31 non-null     float64
#  8   Aux Absolute energy                 31 non-null     float64
#  9   Mill 1 Running hours                31 non-null     float64
#  10  Mill 1 Running hours(MTD)           31 non-null     float64
# ...

# %%
df.describe()
# Out:
#        Anode Production no.  Anode weight  Anode Production\n(Ton)  \
# count             31.000000  3.100000e+01                31.000000
# mean            1671.709677  9.842000e-01              1645.296665
# std              341.068341  4.514300e-16               335.679461
# min              704.000000  9.842000e-01               692.876800
# 25%             1510.500000  9.842000e-01              1486.634100
# 50%             1654.000000  9.842000e-01              1627.866800
# 75%             1930.500000  9.842000e-01              1899.998100
# max             2406.000000  9.842000e-01              2367.985200
#
#        Bath Production  Absolue energy  Mill Absolute energy  \
# count        31.000000       31.000000             31.000000
# mean       1013.223548    86677.741935          24932.903226
# std         232.266415    10149.283952           4093.451839
# min         436.930000    52940.000000          16370.000000
# ...

# %%
df.corr()
# Out:
#                                     Anode Production no.  Anode weight  \
# Anode Production no.                        1.000000e+00  1.093018e-16
# Anode weight                                1.093018e-16  1.000000e+00
# Anode Production\n(Ton)                     1.000000e+00  1.110565e-15
# Bath Production                             1.371520e-01  3.210054e-17
# Absolue energy                              8.719606e-01 -7.052361e-16
# Mill Absolute energy                        8.547635e-02 -2.914265e-17
# Furnace Absolute energy                     9.560156e-01  1.339702e-16
# Aux Absolute energy                         9.078857e-01 -4.745186e-16
# Mill 1 Running hours                        1.396424e-02 -5.081722e-17
# Mill 1 Running hours(MTD)                   2.427805e-02  3.473850e-16
# Mill 2 Running hours                       -1.933596e-01 -3.129760e-16
# Mill 2 Running hours(MTD)                   3.592007e-02  1.650494e-16
# ...

# %%
X= df[['Anode Production no.','Total Furnace running hours','Number of high butt processed','Mould charged/chipping material MT']]
y= df['Absolue energy']
print(X,y)
# Out:
#     Anode Production no.  Total Furnace running hours  \
# 0                   1580                        48.00
# 1                   1557                        51.20
# 2                   1883                        52.15
# 3                   1928                        46.45
# 4                   1471                        48.40
# 5                   1933                        50.85
# 6                   1694                        50.85
# 7                   1608                        40.00
# 8                   1329                        40.30
# 9                   2046                        56.15
# 10                  1745                        50.60
# 11                  1518                        40.00
# 12                  1765                        45.75
# 13                  1365                        43.00
# 14                  1412                        48.30
# 15                  1571                        40.90
# ...

# %%
fig,axes= plt.subplots(nrows=1,ncols=4,figsize=(16,6))
axes[0].plot(df['Anode Production no.'],df['Absolue energy'])
axes[0].set_ylabel('Absolue energy')
axes[0].set_title('Impact of production')

axes[1].plot(df['Total Furnace running hours'],df['Absolue energy'])
axes[1].set_ylabel('Absolue energy')
axes[1].set_title('Impact of furnace running hours')

axes[2].plot(df['Number of high butt processed'],df['Absolue energy'])
axes[2].set_ylabel('Absolue energy')
axes[2].set_title('Impact of high butt processing')

axes[3].plot(df['Mould charged/chipping material MT'],df['Absolue energy'])
axes[3].set_ylabel('Absolue energy')
axes[3].set_title('Impact of mould charged')

plt.tight_layout()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
X_train.shape
# Out:
# (24, 4)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 47038.47905144946

# %%
model.coef_
# Out:
# array([  26.75447799,  -41.32138293,  -20.58181497, -439.52491807])

# %%
model.score(X_train,y_train)
# Out:
# 0.7867011973581699

# %%
test_predict=model.predict(X_test)

# %%
test_predict
# Out:
# array([ 92519.77162667,  90084.9557767 ,  79676.44307466,  86657.6769142 ,
#         90061.9227557 ,  83154.95145826, 105319.18462956])

# %%
test_res= y_test-test_predict
test_res
# Out:
# 2     -3679.771627
# 29    10215.044223
# 13     3503.556925
# 10     5262.323086
# 27     5918.077244
# 25    -7894.951458
# 22     -449.184630
# Name: Absolue energy, dtype: float64

# %%
len(test_res)
# Out:
# 7

# %%
from sklearn.metrics import mean_absolute_error , mean_squared_error,r2_score

# %%
MAE = mean_absolute_error (y_test,test_predict)
MAE
# Out:
# 5274.701313319196

# %%
MSE= mean_squared_error(y_test,test_predict)
MSE
# Out:
# 36487209.532312475

# %%
RMSE= np.sqrt(MSE)
RMSE
# Out:
# 6040.4643474084405

# %%
r2_score(y_test,test_predict)
# Out:
# 0.585692823055328

# %%
sns.displot(test_res,bins=5,kde=True)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
polynomial_converter= PolynomialFeatures(degree=2,include_bias=False)

# %%
polynomial_converter.fit(X)
# Out:
# PolynomialFeatures(include_bias=False)

# %%
polynomial_converter.transform(X)
# Out:
# array([[1.5800000e+03, 4.8000000e+01, 6.1000000e+01, 4.4600000e+00,
#         2.4964000e+06, 7.5840000e+04, 9.6380000e+04, 7.0468000e+03,
#         2.3040000e+03, 2.9280000e+03, 2.1408000e+02, 3.7210000e+03,
#         2.7206000e+02, 1.9891600e+01],
#        [1.5570000e+03, 5.1200000e+01, 1.7100000e+02, 1.4000000e+00,
#         2.4242490e+06, 7.9718400e+04, 2.6624700e+05, 2.1798000e+03,
#         2.6214400e+03, 8.7552000e+03, 7.1680000e+01, 2.9241000e+04,
#         2.3940000e+02, 1.9600000e+00],
#        [1.8830000e+03, 5.2150000e+01, 6.0000000e+01, 3.4300000e+00,
#         3.5456890e+06, 9.8198450e+04, 1.1298000e+05, 6.4586900e+03,
#         2.7196225e+03, 3.1290000e+03, 1.7887450e+02, 3.6000000e+03,
#         2.0580000e+02, 1.1764900e+01],
#        [1.9280000e+03, 4.6450000e+01, 1.0500000e+02, 8.9100000e+00,
#         3.7171840e+06, 8.9555600e+04, 2.0244000e+05, 1.7178480e+04,
#         2.1576025e+03, 4.8772500e+03, 4.1386950e+02, 1.1025000e+04,
# ...

# %%
poly_features= polynomial_converter.fit_transform(X)

# %%
poly_features.shape
# Out:
# (31, 14)

# %%
poly_features[0]
# Out:
# array([1.58000e+03, 4.80000e+01, 6.10000e+01, 4.46000e+00, 2.49640e+06,
#        7.58400e+04, 9.63800e+04, 7.04680e+03, 2.30400e+03, 2.92800e+03,
#        2.14080e+02, 3.72100e+03, 2.72060e+02, 1.98916e+01])

# %%
X_train,X_test,y_train,y_test= train_test_split(poly_features,y,test_size=0.8,random_state=0)

# %%
model= LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
test_predict=model.predict(X_test)

# %%
MSE= mean_squared_error(y_test,test_predict)
MSE
# Out:
# 919368923.3588136

# %%
rmse=np.sqrt(MSE)
rmse
# Out:
# 30321.097001243434

# %%
train_rmse_errors = []

test_rmse_errors = []

for d in range(1,10):
    polynomial_converter = PolynomialFeatures(degree= d,include_bias=False)

    poly_features = polynomial_converter.fit_transform(X)

    X_train,X_test,y_train,y_test=train_test_split(poly_features,y,test_size=0.2,random_state=0)

    model=LinearRegression(fit_intercept=True)
    model.fit(X_train,y_train)

    train_pred=model.predict(X_train)
    test_pred=model.predict(X_test)

    train_RMSE= np.sqrt(mean_squared_error(y_train,train_pred))

    test_RMSE= np.sqrt(mean_squared_error(y_test,test_pred))

    train_rmse_errors.append(train_RMSE)
    test_rmse_errors.append(test_RMSE)

# %%
train_rmse_errors
# Out:
# [4487.022443692033,
#  2908.87070309743,
#  3.9298399226802525e-05,
#  9.884460946090278e-09,
#  3.277423858527843e-09,
#  5.55964423024425e-09,
#  8.358239880972333e-09,
#  8.456500452556873e-09,
#  6.247483574251042e-09]

# %%
test_rmse_errors
# Out:
# [6040.464347408437,
#  9494.641505401945,
#  39936.00794908154,
#  104332.5592475943,
#  157776.69372088448,
#  242589.498595635,
#  377967.17495777976,
#  596103.3487031048,
#  936474.8907540967]

# %%
plt.plot(range(1,10),train_rmse_errors[:10],label="Train")
plt.plot(range(1,10),test_rmse_errors[:10],label="Test")
plt.xlabel("Polynomial Complexity")
plt.ylabel("RMSE")
plt.legend()

# %%
final_poly_converter=PolynomialFeatures(degree=1,include_bias=False)

# %%
final_model=LinearRegression()

# %% [raw]
# final_model.fit(final_poly_converter.fit_transform(X),y)

# %%
from joblib import dump,load

# %%
dump(final_model, 'absolute_power_model.joblib')
# Out:
# ['absolute_power_model.joblib']

# %%
dump(final_poly_converter,"poly_converter.joblib")
# Out:
# ['poly_converter.joblib']
